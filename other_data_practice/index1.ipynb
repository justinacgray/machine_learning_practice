# %% [markdown]
# GroupBy Exercise

# %%
import pandas as pd
import numpy as np

# %%
# dataset has no headers and letting python know that
filename ='https://raw.githubusercontent.com/mGalarnyk/Tutorial_Data/master/Pandas/CalIt2.data'
df = pd.read_csv(filename, header=None)
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10080 entries, 0 to 10079
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       10080 non-null  int64
#  1   1       10080 non-null  object
#  2   2       10080 non-null  object
#  3   3       10080 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 315.1+ KB
#    0         1         2  3
# 0  7  07/24/05  00:00:00  0
# 1  9  07/24/05  00:00:00  0
# 2  7  07/24/05  00:30:00  1
# 3  9  07/24/05  00:30:00  0
# 4  7  07/24/05  01:00:00  0

# %%
# https://www.statology.org/pandas-rename-columns/
df.columns=["Flow_ID", "Date", "Time","Count"]
df.head()
# Out:
#    Flow_ID      Date      Time  Count
# 0        7  07/24/05  00:00:00      0
# 1        9  07/24/05  00:00:00      0
# 2        7  07/24/05  00:30:00      1
# 3        9  07/24/05  00:30:00      0
# 4        7  07/24/05  01:00:00      0

# %%
# selecting one column
df['Date']
# Out:
# 0        07/24/05
# 1        07/24/05
# 2        07/24/05
# 3        07/24/05
# 4        07/24/05
#            ...
# 10075    11/05/05
# 10076    11/05/05
# 10077    11/05/05
# 10078    11/05/05
# 10079    11/05/05
# Name: Date, Length: 10080, dtype: object

# %% [markdown]
# https://www.statology.org/pandas-loc-vs-iloc/
#
# -position of the colon in loc and iloc matters
# -if colon is before means selects all rows/columns from beginning
# -if colon is afterward means selects all rows/columns after first argument

# %%
# selecting multiple columns
# df[['Count', 'Date']]

# selects only rows
# df.loc[['Count', 'Date']]

# this selects all rows for these columns
# df.loc[ 3:6,['Count', 'Date']]

# using iloc- grabbing the columns by index using loc method
# this gives me number of rows NOT columns
# df.iloc[0:2] #selects rows 0 and 1

# Select Columns in Index Range
# first argument selects the rows, second argument for columns 
df.iloc[3:7 ,0:1]
# Out:
#    Flow_ID
# 3        9
# 4        7
# 5        9
# 6        7

# %% [markdown]
# Selecting Data =>
# Select all data for the date July 24 2005 having flow id=7.

# %%
# creating a filter for the date
july_date = df['Date'] == "07/24/05"
flow_id7 = df['Flow_ID'] == 7
# july_date # gives you a bolean true/false
# must be put back in a dataframe
july_date_df = df[july_date]
# july_date_df
flow_id7_df = df[flow_id7]
filtered_df = df[(df['Date'] == "07/24/05") & (df['Flow_ID'] == 7)]
# filtered_df = df.query('Date  == "07/24/05" & Flow_ID == 7')
filtered_df
# Out:
#     Flow_ID      Date      Time  Count
# 0         7  07/24/05  00:00:00      0
# 2         7  07/24/05  00:30:00      1
# 4         7  07/24/05  01:00:00      0
# 6         7  07/24/05  01:30:00      0
# 8         7  07/24/05  02:00:00      0
# 10        7  07/24/05  02:30:00      2
# 12        7  07/24/05  03:00:00      0
# 14        7  07/24/05  03:30:00      0
# 16        7  07/24/05  04:00:00      0
# 18        7  07/24/05  04:30:00      0
# 20        7  07/24/05  05:00:00      0
# 22        7  07/24/05  05:30:00      0
# 24        7  07/24/05  06:00:00      0
# 26        7  07/24/05  06:30:00      0
# 28        7  07/24/05  07:00:00      0
# 30        7  07/24/05  07:30:00      2
# 32        7  07/24/05  08:00:00      0
# 34        7  07/24/05  08:30:00      0
# 36        7  07/24/05  09:00:00      0
# 38        7  07/24/05  09:30:00      1
# 40        7  07/24/05  10:00:00      0
# 42        7  07/24/05  10:30:00      0
# 44        7  07/24/05  11:00:00      1
# 46        7  07/24/05  11:30:00      0
# 48        7  07/24/05  12:00:00      0
# 50        7  07/24/05  12:30:00      0
# 52        7  07/24/05  13:00:00      0
# 54        7  07/24/05  13:30:00      0
# 56        7  07/24/05  14:00:00      0
# 58        7  07/24/05  14:30:00      0
# 60        7  07/24/05  15:00:00      0
# 62        7  07/24/05  15:30:00      0
# 64        7  07/24/05  16:00:00      0
# 66        7  07/24/05  16:30:00      0
# 68        7  07/24/05  17:00:00      1
# 70        7  07/24/05  17:30:00      2
# 72        7  07/24/05  18:00:00      4
# 74        7  07/24/05  18:30:00      1
# 76        7  07/24/05  19:00:00      2
# 78        7  07/24/05  19:30:00      1
# 80        7  07/24/05  20:00:00      0
# 82        7  07/24/05  20:30:00      0
# 84        7  07/24/05  21:00:00      3
# 86        7  07/24/05  21:30:00      2
# 88        7  07/24/05  22:00:00      0
# 90        7  07/24/05  22:30:00      0
# 92        7  07/24/05  23:00:00      2
# 94        7  07/24/05  23:30:00      0

# %% [markdown]
# From the data selected in step 1, sort the result on Count in descending order and output the top 10 rows. Assign the output to a variable named top10.

# %%
# for descending order ascending= False; for ascending order ascending=True
top_10= filtered_df.sort_values('Count', ascending=False)
top10= top_10.head(10)
top10
# Out:
#     Flow_ID      Date      Time  Count
# 72        7  07/24/05  18:00:00      4
# 84        7  07/24/05  21:00:00      3
# 76        7  07/24/05  19:00:00      2
# 92        7  07/24/05  23:00:00      2
# 30        7  07/24/05  07:30:00      2
# 10        7  07/24/05  02:30:00      2
# 86        7  07/24/05  21:30:00      2
# 70        7  07/24/05  17:30:00      2
# 68        7  07/24/05  17:00:00      1
# 74        7  07/24/05  18:30:00      1

# %% [markdown]
# Apply function =>
# For the 10 rows outputted above, use Pandas Apply function to subtract lowest value of the 10 from all of them and then output the average value of the resulting counts

# %%
# using lambda function - similar to a anonymous callback in javascript
# figure out how to use it
# top9 = top10['Count'].apply(lambda lowest_value : top10['Count'] - min(top10['Count']))
# top9_2
def top9(ser):
    # print(ser.iloc[9:])
    # print(ser.iloc[:9])
    # print(ser.iloc[:9].mean())
    return ser.iloc[:9]

top10['Count'].apply(top9)
# top9 = top10['Count'].apply(top10['Count'].sum)
# type(top9['Count']) #Series
# top10.iloc[:9]
# top10['Count']
# top9['Count'].mean()

# top9(top10['Count'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[122], line 11
#       5 def top9(ser):
#       6     # print(ser.iloc[9:])
#       7     # print(ser.iloc[:9])
#       8     # print(ser.iloc[:9].mean())
#       9     return ser.iloc[:9]
# ---> 11 top10['Count'].apply(top9)
#      12 # top9 = top10['Count'].apply(top10['Count'].sum)
#      13 # type(top9['Count']) #Series
#      14 # top10.iloc[:9]
#    (...)
#      17
#      18 # top9(top10['Count'])
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
#    1122 # self.f is Callable
# -> 1123 return self.apply_standard()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/apply.py:1174, in SeriesApply.apply_standard(self)
#    1172     else:
#    1173         values = obj.astype(object)._values
# -> 1174         mapped = lib.map_infer(
#    1175             values,
#    1176             f,
#    1177             convert=self.convert_dtype,
#    1178         )
#    1180 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1181     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1182     #  See also GH#25959 regarding EA support
#    1183     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/_libs/lib.pyx:2924, in pandas._libs.lib.map_infer()
#
# Cell In[122], line 9, in top9(ser)
#       5 def top9(ser):
#       6     # print(ser.iloc[9:])
#       7     # print(ser.iloc[:9])
#       8     # print(ser.iloc[:9].mean())
# ----> 9     return ser.iloc[:9]
#
# AttributeError: 'int' object has no attribute 'iloc'

# %% [markdown]
# Grouping ==>
# Select data in the month of August 2005 having flow id=7
# Group the data based on date and get the max count per date

# %%
# selecting dates for the month of August
# aug_month= df[(df['Date'] > "08/01/2005" ) & (df['Date'] < "08/31/2005")]
aug_month7 = df.query('Date > "08/01/05" &  Date < "08/31/2005" & Flow_ID == 7')
# aug_month = aug_month.groupby(pd.Grouper(key="Date", axis=0, sort=True)).sum()
# aug_month7 = aug_month7.groupby([])
aug_month7
# Out:
#       Flow_ID      Date      Time  Count
# 864         7  08/02/05  00:00:00      2
# 866         7  08/02/05  00:30:00      0
# 868         7  08/02/05  01:00:00      1
# 870         7  08/02/05  01:30:00      0
# 872         7  08/02/05  02:00:00      1
# ...       ...       ...       ...    ...
# 3734        7  08/31/05  21:30:00      0
# 3736        7  08/31/05  22:00:00      2
# 3738        7  08/31/05  22:30:00      1
# 3740        7  08/31/05  23:00:00      0
# 3742        7  08/31/05  23:30:00      2
#
# [1440 rows x 4 columns]
