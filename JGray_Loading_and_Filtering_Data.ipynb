# %% [markdown]
# <a href="https://colab.research.google.com/github/justinacgray/machine_learning_practice/blob/main/JGray_Loading_and_Filtering_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
filename = '/content/drive/MyDrive/Colab_Notebooks/RailsToTrails_National_Count_Data_week.xlsx'
bike_df = pd.read_excel(filename)
bike_df.info()
bike_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Timeframe                   52 non-null     object
#  1   Week of                     52 non-null     datetime64[ns]
#  2    2019 counts (31 counters)  52 non-null     float64
#  3    2020 counts (31 counters)  52 non-null     float64
#  4   2021 Counts                 0 non-null      float64
#  5   Change 2019-2020            52 non-null     float64
#  6   Unnamed: 6                  52 non-null     float64
#  7   Unnamed: 7                  0 non-null      float64
#  8   Unnamed: 8                  1 non-null      float64
#  9   Unnamed: 9                  1 non-null      float64
# dtypes: datetime64[ns](1), float64(8), object(1)
# memory usage: 4.2+ KB
#   Timeframe    Week of   2019 counts (31 counters)  \
# ...

# %%
# bike_df['Week of'].values
# bike_df['Week of'] 
# bike_df['Week of'] > '2020-07-31'

# %%
df_week_filtered = bike_df['Week of'] > '2020-07-31'

# %%
bike_df[df_week_filtered]
# Out:
#    Timeframe    Week of   2019 counts (31 counters)  \
# 0     Week 1 2020-12-30                    167679.0
# 31   Week 32 2020-08-03                    180605.0
# 32   Week 33 2020-08-10                    191450.0
# 33   Week 34 2020-08-17                    168754.0
# 34   Week 35 2020-08-24                    176624.0
# 35   Week 36 2020-08-31                    184806.0
# 36   Week 37 2020-09-07                    157345.0
# 37   Week 38 2020-09-14                    152527.0
# 38   Week 39 2020-09-21                    141072.0
# 39   Week 40 2020-09-28                    135881.0
# 40   Week 41 2020-10-05                    132239.0
# 41   Week 42 2020-10-12                    110816.0
# 42   Week 43 2020-10-19                    110761.0
# 43   Week 44 2020-10-26                    109795.0
# 44   Week 45 2020-11-02                    109766.0
# 45   Week 46 2020-11-09                     86824.0
# 46   Week 47 2020-11-16                     88122.0
# ...

# %%
len(bike_df[df_week_filtered])
# Out:
# 22

# %%
# bike_df[bike_df['Change 2019-2020' ] > .5]
df_change_over_50_percent = bike_df['Change 2019-2020' ] > .5

# %%
bike_df[df_change_over_50_percent]
# Out:
#    Timeframe    Week of   2019 counts (31 counters)  \
# 5     Week 6 2020-02-03                     79780.0
# 6     Week 7 2020-02-10                     65732.0
# 7     Week 8 2020-02-17                     69492.0
# 8     Week 9 2020-02-24                     85688.0
# 9    Week 10 2020-03-02                     84512.0
# 10   Week 11 2020-03-09                    107995.0
# 11   Week 12 2020-03-16                    125440.0
# 12   Week 13 2020-03-23                    136330.0
# 13   Week 14 2020-03-30                    118784.0
# 14   Week 15 2020-04-06                    132033.0
# 15   Week 16 2020-04-13                    133267.0
# 17   Week 18 2020-04-27                    166356.0
# 19   Week 20 2020-05-11                    178534.0
# 28   Week 29 2020-07-13                    166125.0
# 34   Week 35 2020-08-24                    176624.0
# 45   Week 46 2020-11-09                     86824.0
#
# ...

# %%
len(bike_df[df_change_over_50_percent])
# Out:
# 16

# %%
bike_df[df_week_filtered & df_change_over_50_percent]
# len(bike_df[df_week_filtered & df_change_over_50_percent])
# Out:
#    Timeframe    Week of   2019 counts (31 counters)  \
# 34   Week 35 2020-08-24                    176624.0
# 45   Week 46 2020-11-09                     86824.0
#
#      2020 counts (31 counters)  2021 Counts  Change 2019-2020  Unnamed: 6  \
# 34                    273677.0          NaN              0.55  154.948931
# 45                    155805.0          NaN              0.79  179.449231
#
#     Unnamed: 7  Unnamed: 8  Unnamed: 9
# 34         NaN         NaN         NaN
# 45         NaN         NaN         NaN

# %%
# bike_df[bike_df['Change 2019-2020' ] > 1.0]
df_over_100_percent = bike_df['Change 2019-2020'] > 1.0

# %%
bike_df[df_over_100_percent]
# Out:
#    Timeframe    Week of   2019 counts (31 counters)  \
# 7     Week 8 2020-02-17                     69492.0
# 11   Week 12 2020-03-16                    125440.0
# 12   Week 13 2020-03-23                    136330.0
# 13   Week 14 2020-03-30                    118784.0
# 14   Week 15 2020-04-06                    132033.0
#
#      2020 counts (31 counters)  2021 Counts  Change 2019-2020  Unnamed: 6  \
# 7                     149876.0          NaN          1.156737  215.673747
# 11                    367795.0          NaN          1.932039  293.203922
# 12                    372783.0          NaN          1.730000  273.441649
# 13                    280728.0          NaN          1.360000  236.334860
# 14                    419160.0          NaN          2.170000  317.466088
#
#     Unnamed: 7  Unnamed: 8  Unnamed: 9
# 7          NaN         NaN         NaN
# 11         NaN         NaN         NaN
# 12         NaN         NaN         NaN
# 13         NaN         NaN         NaN
# ...

# %%
# this should give me 0 but gives me 4. WHy?
bike_df[df_week_filtered  & df_over_100_percent]
# get this error "unsupported operand type(s) for &: 'float' and 'bool'"
# bike_df[df_week_filtered].dtypes
# bike_df[df_over_100_percent].dtypes
# bike_df[df_week_filtered] & bike_df[df_over_100_percent]
# Out:
# Empty DataFrame
# Columns: [Timeframe, Week of,  2019 counts (31 counters),  2020 counts (31 counters), 2021 Counts, Change 2019-2020, Unnamed: 6, Unnamed: 7, Unnamed: 8, Unnamed: 9]
# Index: []
